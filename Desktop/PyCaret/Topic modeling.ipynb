# %%
from pycaret.datasets import get_data

# %%
data = get_data('kiva')
data = data.head(1500)
# Out:
#               country                                                 en  \
# 0  Dominican Republic  "Banco Esperanza" is a group of 10 women looki...
# 1  Dominican Republic  "Caminemos Hacia Adelante" or "Walking Forward...
# 2  Dominican Republic  "Creciendo Por La Union" is a group of 10 peop...
# 3  Dominican Republic  "Cristo Vive" ("Christ lives" is a group of 10...
# 4  Dominican Republic  "Cristo Vive" is a large group of 35 people, 2...
#
#   gender  loan_amount nonpayment    sector  status
# 0      F         1225    partner    Retail       0
# 1      F         1975     lender  Clothing       0
# 2      F         2175    partner  Clothing       0
# 3      F         1425    partner  Clothing       0
# 4      F         4025    partner      Food       0

# %%
from pycaret.nlp import *

# %%
s = setup(data, target='en')
# Out:
# <style  type="text/css" >
# </style><table id="T_0ae67980_888d_11ea_abdb_48452091a1c6" ><thead>    <tr>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_0ae67980_888d_11ea_abdb_48452091a1c6row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_0ae67980_888d_11ea_abdb_48452091a1c6row0_col1" class="data row0 col1" >7178</td>
#             </tr>
#             <tr>
#                                 <td id="T_0ae67980_888d_11ea_abdb_48452091a1c6row1_col0" class="data row1 col0" ># Documents</td>
#                         <td id="T_0ae67980_888d_11ea_abdb_48452091a1c6row1_col1" class="data row1 col1" >1500</td>
#             </tr>
#             <tr>
#                                 <td id="T_0ae67980_888d_11ea_abdb_48452091a1c6row2_col0" class="data row2 col0" >Vocab Size</td>
#                         <td id="T_0ae67980_888d_11ea_abdb_48452091a1c6row2_col1" class="data row2 col1" >4648</td>
#             </tr>
#             <tr>
#                                 <td id="T_0ae67980_888d_11ea_abdb_48452091a1c6row3_col0" class="data row3 col0" >Custom Stopwords</td>
#                         <td id="T_0ae67980_888d_11ea_abdb_48452091a1c6row3_col1" class="data row3 col1" >False</td>
#             </tr>
#     </tbody></table>

# %%
data.head()
# Out:
#               country                                                 en  \
# 0  Dominican Republic  "Banco Esperanza" is a group of 10 women looki...
# 1  Dominican Republic  "Caminemos Hacia Adelante" or "Walking Forward...
# 2  Dominican Republic  "Creciendo Por La Union" is a group of 10 peop...
# 3  Dominican Republic  "Cristo Vive" ("Christ lives" is a group of 10...
# 4  Dominican Republic  "Cristo Vive" is a large group of 35 people, 2...
#
#   gender  loan_amount nonpayment    sector  status
# 0      F         1225    partner    Retail       0
# 1      F         1975     lender  Clothing       0
# 2      F         2175    partner  Clothing       0
# 3      F         1425    partner  Clothing       0
# 4      F         4025    partner      Food       0

# %%
s[7]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-34-b035325af127> in <module>
# ----> 1 s[7]
#
# IndexError: tuple index out of range

# %%
lda = create_model(model='lda', multi_core=True)

# %%
assign_model(lda)
# Out:
#                  country                                                 en  \
# 0     Dominican Republic  woman look receive small loan take small loan ...
# 1     Dominican Republic  caminemos walk forward group entrepreneur seek...
# 2     Dominican Republic  group people hope start business group look re...
# 3     Dominican Republic  live group woman look receive first loan young...
# 4     Dominican Republic  vive large group people hope take loan many se...
# ...                  ...                                                ...
# 1495  Dominican Republic  year old mother son attend school start busine...
# 1496  Dominican Republic  coordinator entrepreneur friend take second lo...
# 1497  Dominican Republic  start sell snack push street able open permane...
# 1498  Dominican Republic  woman live husband child age small community c...
# 1499  Dominican Republic  make bread year say main difficulty buy flour ...
#
#      gender  loan_amount nonpayment    sector  status   Topic_0   Topic_1  \
# 0         F         1225    partner    Retail       0  0.004245  0.004220
# 1         F         1975     lender  Clothing       0  0.003718  0.322818
# 2         F         2175    partner  Clothing       0  0.005164  0.005249
# 3         F         1425    partner  Clothing       0  0.003994  0.003941
# 4         F         4025    partner      Food       0  0.004034  0.003982
# ...     ...          ...        ...       ...     ...       ...       ...
# 1495      F          475    partner  Clothing       1  0.235341  0.006789
# 1496      F          900     lender    Retail       0  0.041278  0.003472
# 1497      M          475    partner      Food       0  0.005639  0.983213
# 1498      F         4000    partner  Clothing       0  0.368938  0.005542
# 1499      F          300    partner      Food       0  0.003561  0.393631
#
#        Topic_2   Topic_3 Dominant_Topic  Perc_Dominant_Topic
# 0     0.987184  0.004351        Topic 2                 0.99
# 1     0.588700  0.084765        Topic 2                 0.59
# 2     0.984510  0.005077        Topic 2                 0.98
# 3     0.988103  0.003963        Topic 2                 0.99
# 4     0.987969  0.004014        Topic 2                 0.99
# ...        ...       ...            ...                  ...
# 1495  0.169089  0.588781        Topic 3                 0.59
# 1496  0.488283  0.466968        Topic 2                 0.49
# 1497  0.005587  0.005560        Topic 1                 0.98
# 1498  0.620150  0.005370        Topic 2                 0.62
# 1499  0.003591  0.599218        Topic 3                 0.60
#
# [1500 rows x 13 columns]

# %%
plot_model(lda, plot='topic_distribution')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>
#
#
#             <div id="0bf23587-4e42-4205-975d-c38e695e026e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("0bf23587-4e42-4205-975d-c38e695e026e")) {
#                     Plotly.newPlot(
#                         '0bf23587-4e42-4205-975d-c38e695e026e',
#                         [{"alignmentgroup": "True", "customdata": [["business, sell, loan, year, community, child, buy, good, live, woman"], ["loan, business, group, sell, member, community, store, small, child, buy"], ["loan, business, child, group, small, sell, hope, live, support, able"], ["business, loan, sell, year, product, entrepreneur, child, buy, customer, old"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "Topic=%{x}<br>Documents=%{y}<br>Keyword=%{customdata[0]}", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["Topic 0", "Topic 1", "Topic 2", "Topic 3"], "xaxis": "x", "y": [440, 253, 367, 440], "yaxis": "y"}],
#                         {"barmode": "relative", "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpo ...

# %%
plot_model(lda, plot='tsne' )
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>
#
#
#             <div id="5cfb647b-aafc-46cc-a9f6-16ffef4d7571" class="plotly-graph-div" style="height:800px; width:900px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("5cfb647b-aafc-46cc-a9f6-16ffef4d7571")) {
#                     Plotly.newPlot(
#                         '5cfb647b-aafc-46cc-a9f6-16ffef4d7571',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "Dominant_Topic=Topic 0<br>0=%{x}<br>1=%{y}<br>2=%{z}", "legendgroup": "Dominant_Topic=Topic 0", "marker": {"color": "#636efa", "opacity": 0.7, "symbol": "circle"}, "mode": "markers", "name": "Dominant_Topic=Topic 0", "scene": "scene", "showlegend": true, "type": "scatter3d", "x": [-2.362353801727295, 2.206136703491211, -1.2536699771881104, 15.967594146728516, 8.041621208190918, 5.943308353424072, -1.3270962238311768, 2.6297149658203125, -1.3033443689346313, 2.2855777740478516, -2.0282511711120605, 2.138702154159546, 2.2733383178710938, -2.629462718963623, 11.361915588378906, 0.07717924565076828, -2.4724955558776855, 1.002037763595581, -2.2608697414398193, -3.013322591781616, 7.800910472869873, 3.457796335220337, 2.636201858520508, 1.902775764465332, 10.329916954040527, 0.9780234098434448, 0.9340618252754211, 15.999916076660156, 0.8718262910842896, 10.232475280761719, 0.6256619691848755, -1.8963384628295898, 15.497570037841797, -0.25260740518569946, 11.430173873901367, -2.455754518508911, 13.59030532836914, 1.2217497825622559, 0.8902794122
# %%
assign_model(lda)
# Out:
#                  country                                                 en  \
# 0     Dominican Republic  woman look receive small loan take small loan ...
# 1     Dominican Republic  caminemos walk forward group entrepreneur seek...
# 2     Dominican Republic  group people hope start business group look re...
# 3     Dominican Republic  live group woman look receive first loan young...
# 4     Dominican Republic  vive large group people hope take loan many se...
# ...                  ...                                                ...
# 1495  Dominican Republic  year old mother son attend school start busine...
# 1496  Dominican Republic  coordinator entrepreneur friend take second lo...
# 1497  Dominican Republic  start sell snack push street able open permane...
# 1498  Dominican Republic  woman live husband child age small community c...
# 1499  Dominican Republic  make bread year say main difficulty buy flour ...
#
#      gender  loan_amount nonpayment    sector  status   Topic_0   Topic_1  \
# 0         F         1225    partner    Retail       0  0.004245  0.004220
# 1         F         1975     lender  Clothing       0  0.003718  0.323049
# 2         F         2175    partner  Clothing       0  0.005165  0.005249
# 3         F         1425    partner  Clothing       0  0.003998  0.003941
# 4         F         4025    partner      Food       0  0.004035  0.003982
# ...     ...          ...        ...       ...     ...       ...       ...
# 1495      F          475    partner  Clothing       1  0.232679  0.006795
# 1496      F          900     lender    Retail       0  0.041287  0.003472
# 1497      M          475    partner      Food       0  0.005640  0.983213
# 1498      F         4000    partner  Clothing       0  0.368918  0.005542
# 1499      F          300    partner      Food       0  0.003561  0.393694
#
#        Topic_2   Topic_3 Dominant_Topic  Perc_Dominant_Topic
# 0     0.987183  0.004352        Topic 2                 0.99
# 1     0.588693  0.084541        Topic 2                 0.59
# 2     0.984509  0.005077        Topic 2                 0.98
# 3     0.988098  0.003963        Topic 2                 0.99
# 4     0.987969  0.004014        Topic 2                 0.99
# ...        ...       ...            ...                  ...
# 1495  0.169992  0.590534        Topic 3                 0.59
# 1496  0.488279  0.466963        Topic 2                 0.49
# 1497  0.005587  0.005560        Topic 1                 0.98
# 1498  0.620170  0.005370        Topic 2                 0.62
# 1499  0.003591  0.599155        Topic 3                 0.60
#
# [1500 rows x 13 columns]

# %%
plot_model(lda, plot='bigram')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>
#
#
#             <div id="6470e861-bf62-40d8-9aca-be9803e226d8" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("6470e861-bf62-40d8-9aca-be9803e226d8")) {
#                     Plotly.newPlot(
#                         '6470e861-bf62-40d8-9aca-be9803e226d8',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "count", "orientation": "v", "text": "", "type": "bar", "x": ["year old", "request loan", "loan buy", "hope business", "small business", "year ago", "work hard", "grocery store", "operate business", "hard work", "start small", "mother child", "enough money", "start business", "business allow", "receive loan", "loan purchase", "small grocery", "operate small", "single mother", "use loan", "good education", "support child", "increase income", "people community", "business year", "buy good", "make live", "business sell", "attend school", "community santo_domingo", "support family", "run business", "run small", "month ago", "woman live", "start sell", "old woman", "proud mother", "keep work", "customer need", "improve family", "sell clothing", "business successful", "child sell", "entrepreneur explain", "move business", "child live", "entrepreneur request", "beauty product", "sell good", "earn live", "entrepreneur hope", "work woman", "clothing bulk", "husband child", "business selling", "loan entrepreneur", "small cafeteria", "make business", "entrepreneur sell", "go school", "old daughter", "second loan", "keep support", "business grow", "live community", "woman community", "buy clothing", "together woman", "old mother", "business help", "people neighborhood", "buy new", "clothing store", "business forward", "add new", "loan fsma", "good order", "improve_familys living_condition", "family living_condition", "sell women", "school go", "husband work", "child boy", "live husband", "well income", "try hard", "loan together", "use clothing", "provide good", "small community", "say keep", "women clothing", "loan start", "entrepreneur buy", "woman sell", "hard make", "women clothe", "increase revenue"], "y": [180, 126, 122, 100, 95, 84, 69, 66, 59, 53, 52, 51, 50, 50, 49, 48, 47, 42, 41, 40, 40, 40, 40, 39, 38, 38, 36, 36, 35, 33, 32, 32, 32, 31, 31, 30, 29, 28, 28, 27, 27, 27, 27, 26, 26, 26, 25, 24, 24, 24, 24, 23, 23, 23, 23, 23, 22, 22, 22, 22, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 20, 20, 20, 19, 19, 19, 19, 19, 19, 19, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {" ...

# %%
plot_model(lda, plot='wordcloud')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
plot_model(lda, plot='trigram')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>
#
#
#             <div id="6bbd7a3e-8298-4904-83bc-a6a308795d00" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("6bbd7a3e-8298-4904-83bc-a6a308795d00")) {
#                     Plotly.newPlot(
#                         '6bbd7a3e-8298-4904-83bc-a6a308795d00',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "count", "orientation": "v", "text": "", "type": "bar", "x": ["request loan buy", "small grocery store", "start small business", "hope business allow", "small business sell", "keep work hard", "use loan buy", "hard work woman", "request loan purchase", "business year ago", "entrepreneur request loan", "year old daughter", "small business selling", "move business forward", "year old mother", "receive loan together", "loan together woman", "loan buy good", "loan entrepreneur buy", "start business year", "improve family living_condition", "provide good education", "lift family poverty", "buy clothing bulk", "start year ago", "child attend school", "year old child", "make business successful", "say keep work", "loan buy clothing", "mother school go", "run small business", "year old woman", "school go child", "year old proud", "year old husband", "entrepreneur hope business", "year old single", "single mother child", "keep_satisfying customer need", "operate small business", "support child education", "old mother child", "old proud mother", "hope business help", "live husband child", "loan buy new", "year old live", "old woman live", "hope business growth", "plans_using loan buy", "proud mother child", "entrepreneur receive loan", "grocery store start", "operate small grocery", "live community santo_domingo", "enough money buy", "child girl boy", "business growth help", "hope business grow", "hope business keep", "loan start small", "operate business house", "money enjoy_golden year", "sell pant shoe", "old single mother", "year old son", "sell beauty product", "run small grocery", "request second loan", "request loan start", "loan together_following woman", "enough money enjoy_golden", "store start year", "work hard order", "woman operate small", "go back school", "work hard provide", "business month ago", "business keep grow", "year ago start", "generate well income", "age year old", "mother year old", "save enough money", "keep operate business", "large variety good", "hard make live", "receive loan together_following", "separate husband year", "plan start small", "operate small cafeteria", "owns_operate small grocery", "woman mother child", "buy good order", "try hard make", "support children study", "support children education", "loan buy raw_material", "sell use clothing"], "y": [45, 42, 37, 35, 26, 24, 24, 23, 22, 20, 19, 19, 19, 18, 17, 17, 16, 16, 16, 16, 15, 15, 15, 15, 14, 14, 14, 14, 13, 13, 13, 13, 13, 13, 13, 13, 13, 12, 12, 12, 11, 11, 11, 11, 11, 11, 10, 10, 10, 10, 10, 10, 10, 10, 10, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {" ...

# %%
tuned_model = tune_model(model='lda', multi_core = True, supervised_target='status')
# Out:
# IntProgress(value=0, description='Processing: ', max=25)
# Output()
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>
#
#
#             <div id="5cfe0d86-0929-4708-a00d-4d0a30c497ea" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("5cfe0d86-0929-4708-a00d-4d0a30c497ea")) {
#                     Plotly.newPlot(
#                         '5cfe0d86-0929-4708-a00d-4d0a30c497ea',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "Metric=Accuracy<br># Topics=%{x}<br>Score=%{y}", "legendgroup": "Metric=Accuracy", "line": {"color": "#636efa", "dash": "solid", "shape": "linear"}, "mode": "lines", "name": "Metric=Accuracy", "showlegend": true, "type": "scatter", "x": [2, 4, 8, 16, 32, 64, 100, 200, 300, 400], "xaxis": "x", "y": [0.7786666666666666, 0.8086666666666666, 0.7873333333333333, 0.7733333333333333, 0.8126666666666666, 0.8173333333333334, 0.788, 0.794, 0.7966666666666666, 0.8033333333333333], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "Metric=AUC<br># Topics=%{x}<br>Score=%{y}", "legendgroup": "Metric=AUC", "line": {"color": "#EF553B", "dash": "solid", "shape": "linear"}, "mode": "lines", "name": "Metric=AUC", "showlegend": true, "type": "scatter", "x": [2, 4, 8, 16, 32, 64, 100, 200, 300, 400], "xaxis": "x", "y": [0.8236826262998961, 0.8675465340958743, 0.8378273407839671, 0.8367665478837545, 0.867599937857441, 0.857093961491033, 0.8225878491877773, 0.8231291691345678, 0.8094602336171824, 0.8376380001747759], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "Metric=Recall<br># Topics=%{x}<br>Score=%{y}", "legendgroup": "Metric=Recall", "line": {"color": "#00cc96", "dash": "solid", "shape": "linear"}, "mode": "lines", "name": "Metric=Recall", "showlegend": true, "type": "scatter", "x": [2, 4, 8, 16, 32, 64, 100, 200, 300, 400], "xaxis": "x", "y": [0.19613259668508287, 0.5580110497237569, 0.4088397790055249, 0.3287292817679558, 0.5, 0.5524861878453039, 0.430939226519337, 0.356353591160221, 0.35359116022099446, 0.3674033149171271], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "Metric=Precision<br># Topics=%{x}<br>Score=%{y}", "legendgroup": "Metric=Precision", "line": {"color": "#ab63fa", "dash": "solid", "shape": "linear"}, "mode": "lines", "name": "Metric=Precision", "showlegend": true, "type": "scatter", "x": [2, 4, 8, 16, 32, 64, 100, 200, 300, 400], "xaxis": "x", "y": [0.6339285714285714, 0.6139817629179332, 0.5849802371541502, 0.5509259259259259, 0.6441281138790036, 0.6410256410256411, 0.582089552238806, 0.6292682926829268, 0.6432160804020101, 0.6683417085427136], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "Metric=F1<br># Topics=%{x}<br>Score=%{y}", "legendgroup": "Metric=F1", "line": {"color": "#FFA15A", "dash": "solid", "shape": "linear"}, "mode": "lines", "name": "Metric=F1", "showlegend": true, "type": "scatter", "x": [2, 4, 8, 16, 32, 64, 100, 200, 300, 400], "xaxis": "x", "y": [0.29957805907172996, 0.5846599131693198, 0.48130081300813005, 0.4117647058823529, 0.5629860031104199, 0.5934718100890208, 0.4952380952380952, 0.455026455026455, 0.4563279857397504, 0.4741532976827095], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "Metric=Kappa<br># Topics=%{x}<br>Score=%{y}", "legendgroup": "Metric=Kappa", "line": {"color": "#19d3f3", "dash": "solid", "shape": "linear"}, "mode": "lines", "name": "Metric=Kappa", "showlegend": true, "type": "scatter", "x": [2, 4, 8, 16, 32, 64, 100, 200, 300, 400], "xaxis": "x", "y": [0.20941337837666207, 0.4607317513127831, 0.35279064231301926, 0.2823128102941673, 0.44616427700458317, 0.47650781035062517, 0.3648198059038469, 0.33981882406563346, 0.3440145449540022, 0.3655222647915759], "yaxis": "y"}],
#                         {"legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "plot_bgcolor": "rgb(245,245,245)", "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, ...
# Best Model: Latent Dirichlet Allocation | # Topics: 64 | Accuracy : 0.8173

# %%
assign_model(tuned_model)
# Out:
#                  country                                                 en  \
# 0     Dominican Republic  woman look receive small loan take small loan ...
# 1     Dominican Republic  caminemos walk forward group entrepreneur seek...
# 2     Dominican Republic  group people hope start business group look re...
# 3     Dominican Republic  live group woman look receive first loan young...
# 4     Dominican Republic  vive large group people hope take loan many se...
# ...                  ...                                                ...
# 1495  Dominican Republic  year old mother son attend school start busine...
# 1496  Dominican Republic  coordinator entrepreneur friend take second lo...
# 1497  Dominican Republic  start sell snack push street able open permane...
# 1498  Dominican Republic  woman live husband child age small community c...
# 1499  Dominican Republic  make bread year say main difficulty buy flour ...
#
#      gender  loan_amount nonpayment    sector  status   Topic_0   Topic_1  \
# 0         F         1225    partner    Retail       0  0.000248  0.000248
# 1         F         1975     lender  Clothing       0  0.000217  0.000217
# 2         F         2175    partner  Clothing       0  0.000306  0.000306
# 3         F         1425    partner  Clothing       0  0.000237  0.000237
# 4         F         4025    partner      Food       0  0.000237  0.000237
# ...     ...          ...        ...       ...     ...       ...       ...
# 1495      F          475    partner  Clothing       1  0.000381  0.000381
# 1496      F          900     lender    Retail       0  0.000214  0.000214
# 1497      M          475    partner      Food       0  0.000333  0.000333
# 1498      F         4000    partner  Clothing       0  0.000326  0.000326
# 1499      F          300    partner      Food       0  0.000237  0.000237
#
#        Topic_2  ...  Topic_56  Topic_57  Topic_58  Topic_59  Topic_60  \
# 0     0.000248  ...  0.000248  0.000248  0.000248  0.000248  0.000248
# 1     0.000217  ...  0.000217  0.000217  0.000217  0.000217  0.000217
# 2     0.000306  ...  0.000306  0.000306  0.000306  0.000306  0.000306
# 3     0.000237  ...  0.000237  0.000237  0.000237  0.000237  0.000237
# 4     0.000237  ...  0.000237  0.000237  0.000237  0.000237  0.000237
# ...        ...  ...       ...       ...       ...       ...       ...
# 1495  0.000381  ...  0.000381  0.000381  0.000381  0.000381  0.000381
# 1496  0.000214  ...  0.000214  0.000214  0.000214  0.000214  0.000214
# 1497  0.000333  ...  0.000333  0.037415  0.000333  0.000333  0.000333
# 1498  0.000326  ...  0.000326  0.000326  0.000326  0.000326  0.000326
# 1499  0.000237  ...  0.000237  0.000237  0.000237  0.000237  0.000237
#
#       Topic_61  Topic_62  Topic_63  Dominant_Topic  Perc_Dominant_Topic
# 0     0.000248  0.000248  0.139610        Topic 26                 0.58
# 1     0.000217  0.000217  0.000217         Topic 9                 0.99
# 2     0.000306  0.000306  0.000306        Topic 26                 0.98
# 3     0.000237  0.000237  0.000237        Topic 26                 0.60
# 4     0.000237  0.000237  0.000237        Topic 28                 0.81
# ...        ...       ...       ...             ...                  ...
# 1495  0.000381  0.000381  0.246630        Topic 12                 0.61
# 1496  0.000214  0.078642  0.226979         Topic 9                 0.31
# 1497  0.000333  0.000333  0.000333        Topic 53                 0.34
# 1498  0.021545  0.000326  0.000326        Topic 45                 0.64
# 1499  0.000237  0.066313  0.107807        Topic 15                 0.18
#
# [1500 rows x 73 columns]
