# %% [markdown]
# # 1. Install PyCaret

# %%
# for google notebook
# !pip install pycaret

# %%
# # Only if you are running this on google colab
# from pycaret.utils import enable_colab
# enable_colab()
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
# Colab mode activated.

# %% [markdown]
# # 2. Import Dataset

# %%
# from google.colab import drive
# drive.mount('/content/gdrive')
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import pandas as pd
path = './winequality-data.csv'
data = pd.read_csv('winequality-data.csv')

# %% [markdown]
# # 3. Setup Experiment

# %%
#import classification module
from pycaret.classification import *
exp_clf = setup(data, normalize = True, target = 'quality', session_id = 123)
# Out:
#
# Setup Succesfully Completed!
# <style  type="text/css" >
#     #T_f1e6a846_87c1_11ea_b96b_48452091a1c6row15_col1 {
#             background-color:  lightgreen;
#         }</style><table id="T_f1e6a846_87c1_11ea_b96b_48452091a1c6" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f1e6a846_87c1_11ea_b96b_48452091a1c6level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_f1e6a846_87c1_11ea_b96b_48452091a1c6row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_f1e6a846_87c1_11ea_b96b_48452091a1c6row0_col1" class="data row0 col1" >123</td>
#             </tr>
#             <tr>
#                         <th id="T_f1e6a846_87c1_11ea_b96b_48452091a1c6level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_f1e6a846_87c1_11ea_b96b_48452091a1c6row1_col0" class="data row1 col0" >Target Type</td>
#                         <td id="T_f1e6a846_87c1_11ea_b96b_48452091a1c6row1_col1" class="data row1 col1" >Multiclass</td>
#             </tr>
#             <tr>
#                         <th id="T_f1e6a846_87c1_11ea_b96b_48452091a1c6level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_f1e6a846_87c1_11ea_b96b_48452091a1c6row2_col0" class="data row2 col0" >Label Encoded</td>
#                         <td id="T_f1e6a846_87c1_11ea_b96b_48452091a1c6row2_col1" class="data row2 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_f1e6a846_87c1_11ea_b96b_48452091a1c6level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_f1e6a846_87c1_11ea_b96b_48452091a1c6row3_col0" class="data row3 col0" >Original Data</td>
#                         <td id="T_f1e6a846_87c1_11ea_b96b_48452091a1c6row3_col1" class="data row3 col1" >(3918, 13)</td>
#             </tr>
#             <tr>
#                         <th id="T_f1e6a846_87c1_11ea_b96b_48452091a1c6level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_f1e6a846_87c1_11ea_b96b_48452091a1c6row4_col0" class="data row4 col0" >Missing Values </td>
#                         <td id="T_f1e6a846_87c1_11ea_b96b_48452091a1c6row4_col1" class="data row4 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_f1e6a846_87c1_11ea_b96b_48452091a1c6level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_f1e6a846_87c1_11ea_b96b_48452091a1c6row5_col0" class="data row5 col0" >Numeric Features </td>
#                         <td id="T_f1e6a846_87c1_11ea_b96b_48452091a1c6row5_col1" class="data row5 col1" >12</td>
#             </tr>
#             <tr>
#                         <th id="T_f1e6a846_87c1_11ea_b96b_48452091a1c6level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_f1e6a846_87c1_11ea_b96b_48452091a1c6row6_col0" class="data row6 col0" >Categorical Features </td>
#                         <td id="T_f1e6a846_87c1_11ea_b96b_48452091a1c6row6_col1" class="data row6 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_f1e6a846_87c1_11ea_b96b_48452091a1c6level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_f1e6a846_87c1_11ea_b96b_48452091a1c6row7_col0" class="data row7 col0" >Ordinal Features </td>
#                         <td id="T_f1e6a846_87c1_11ea_b96b_48452091a1c6row7_col1" class="data row7 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_f1e6a846_87c1_11ea_b96b_48452091a1c6level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_f1e6a846_87c1_11ea_b96b_48452091a1c6row8_col0" class="data row8 col0" >High Cardinality Features </td>
#                         <td id="T_f1e6a846_87c1_11ea_b96b_48452091a1c6row8_col1" class="data row8 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_f1e6a846_87c1_11ea_b96b_48452091a1c6level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_f1e6a846_87c1_11ea_b96b_48452091a1c6row9_col0" class="data row9 col0" >High Cardinality Method </td>
#                         <td id="T_f1e6a846_87c1_11ea_b96b_48452091a1c6row9_col1" class="data row9 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_f1e6a846_87c1_11ea_b96b_48452091a1c6level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_f1e6a846_87c1_11ea_b96b_48452091a1c6row10_col0" class="data row10 col0" >Sampled Data</td>
#                         <td id="T_f1e6a846_87c1_11ea_b96b_48452091a1c6row10_col1" class="data row10 col1" >(3918, 13)</td>
#             </tr>
#             <tr>
#                         <th id="T_f1e6a846_87c1_11ea_b96b_48452091a1c6level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_f1e6a846_87c1_11ea_b96b_48452091a1c6row11_col0" class="data row11 col0" >Transformed Train Set</td>
#                         <td id="T_f1e6a846_87c1_11ea_b96b_48452091a1c6row11_col1" class="data row11 col1" >(2742, 11)</td>
#             </tr>
#             <tr>
#                         <th id="T_f1e6a846_87c1_11ea_b96b_48452091a1c6level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_f1e6a846_87c1_11ea_b96b_48452091a1c6row12_col0" class="data row12 col0" >Transformed Test Set</td>
#                         <td id="T_f1e6a846_87c1_11ea_b96b_48452091a1c6row12_col1" class="data row12 col1" >(1176, 11)</td>
#             </tr>
#             <tr>
#                         <th id="T_f1e6a846_87c1_11ea_b96b_48452091a1c6level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_f1e6a846_87c1_11ea_b96b_48452091a1c6row13_col0" class="data row13 col0" >Numeric Imputer </td>
#                         <td id="T_f1e6a846_87c1_11ea_b96b_48452091a1c6row13_col1" class="data row13 col1" >mean</td>
#             </tr>
#             <tr>
#                         <th id="T_f1e6a846_87c1_11ea_b96b_48452091a1c6level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_f1e6a846_87c1_11ea_b96b_48452091a1c6row14_col0" class="data row14 col0" >Categorical Imputer </td>
#                         <td id="T_f1e6a846_87c1_11ea_b96b_48452091a1c6row14_col1" class="data row14 col1" >constant</td>
#             </tr>
#             <tr>
#                         <th id="T_f1e6a846_87c1_11ea_b96b_48452091a1c6level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_f1e6a846_87c1_11ea_b96b_48452091a1c6row15_col0" class="data row15 col0" >Normalize </td>
#                         <td id="T_f1e6a846_87c1_11ea_b96b_48452091a1c6row15_col1" class="data row15 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_f1e6a846_87c1_11ea_b96b_48452091a1c6level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_f1e6a846_87c1_11ea_b96b_48452091a1c6row16_col0" class="data row16 col0" >Normalize Method </td>
#                         <td id="T_f1e6a846_87c1_11ea_b96b_48452091a1c6row16_col1" class="data row16 col1" >zscore</td>
#             </tr>
#             <tr>
#                         <th id="T_f1e6a846_87c1_11ea_b96b_48452091a1c6level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_f1e6a846_87c1_11ea_b96b_48452091a1c6row17_col0" class="data row17 col0" >Transformation </td>
#                         <td id="T_f1e6a846_87c1_11ea_b96b_48452091a1c6row17_col1" class="data row17 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_f1e6a846_87c1_11ea_b96b_48452091a1c6level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_f1e6a846_87c1_11ea_b96b_48452091a1c6row18_col0" class="data row18 col0" >Transformation Method </td>
#                         <td i

# %% [markdown]
# # 4. Create Model

# %%
compare_models(blacklist = None, fold = 10,  round = 4, turbo = True)
# Out:
# <style  type="text/css" >
#     #T_b5ef3ae8_87c0_11ea_9ece_48452091a1c6 th {
#           text-align: left;
#     }    #T_b5ef3ae8_87c0_11ea_9ece_48452091a1c6row0_col0 {
#             text-align:  left;
#         }    #T_b5ef3ae8_87c0_11ea_9ece_48452091a1c6row0_col1 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_b5ef3ae8_87c0_11ea_9ece_48452091a1c6row0_col2 {
#             text-align:  left;
#         }    #T_b5ef3ae8_87c0_11ea_9ece_48452091a1c6row0_col3 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_b5ef3ae8_87c0_11ea_9ece_48452091a1c6row0_col4 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_b5ef3ae8_87c0_11ea_9ece_48452091a1c6row0_col5 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_b5ef3ae8_87c0_11ea_9ece_48452091a1c6row0_col6 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_b5ef3ae8_87c0_11ea_9ece_48452091a1c6row1_col0 {
#             text-align:  left;
#         }    #T_b5ef3ae8_87c0_11ea_9ece_48452091a1c6row1_col1 {
#             : ;
#             text-align:  left;
#         }    #T_b5ef3ae8_87c0_11ea_9ece_48452091a1c6row1_col2 {
#             text-align:  left;
#         }    #T_b5ef3ae8_87c0_11ea_9ece_48452091a1c6row1_col3 {
#             : ;
#             text-align:  left;
#         }    #T_b5ef3ae8_87c0_11ea_9ece_48452091a1c6row1_col4 {
#             : ;
#             text-align:  left;
#         }    #T_b5ef3ae8_87c0_11ea_9ece_48452091a1c6row1_col5 {
#             : ;
#             text-align:  left;
#         }    #T_b5ef3ae8_87c0_11ea_9ece_48452091a1c6row1_col6 {
#             : ;
#             text-align:  left;
#         }    #T_b5ef3ae8_87c0_11ea_9ece_48452091a1c6row2_col0 {
#             text-align:  left;
#         }    #T_b5ef3ae8_87c0_11ea_9ece_48452091a1c6row2_col1 {
#             : ;
#             text-align:  left;
#         }    #T_b5ef3ae8_87c0_11ea_9ece_48452091a1c6row2_col2 {
#             text-align:  left;
#         }    #T_b5ef3ae8_87c0_11ea_9ece_48452091a1c6row2_col3 {
#             : ;
#             text-align:  left;
#         }    #T_b5ef3ae8_87c0_11ea_9ece_48452091a1c6row2_col4 {
#             : ;
#             text-align:  left;
#         }    #T_b5ef3ae8_87c0_11ea_9ece_48452091a1c6row2_col5 {
#             : ;
#             text-align:  left;
#         }    #T_b5ef3ae8_87c0_11ea_9ece_48452091a1c6row2_col6 {
#             : ;
#             text-align:  left;
#         }    #T_b5ef3ae8_87c0_11ea_9ece_48452091a1c6row3_col0 {
#             text-align:  left;
#         }    #T_b5ef3ae8_87c0_11ea_9ece_48452091a1c6row3_col1 {
#             : ;
#             text-align:  left;
#         }    #T_b5ef3ae8_87c0_11ea_9ece_48452091a1c6row3_col2 {
#             text-align:  left;
#         }    #T_b5ef3ae8_87c0_11ea_9ece_48452091a1c6row3_col3 {
#             : ;
#             text-align:  left;
#         }    #T_b5ef3ae8_87c0_11ea_9ece_48452091a1c6row3_col4 {
#             : ;
#             text-align:  left;
#         }    #T_b5ef3ae8_87c0_11ea_9ece_48452091a1c6row3_col5 {
#             : ;
#             text-align:  left;
#         }    #T_b5ef3ae8_87c0_11ea_9ece_48452091a1c6row3_col6 {
#             : ;
#             text-align:  left;
#         }    #T_b5ef3ae8_87c0_11ea_9ece_48452091a1c6row4_col0 {
#             text-align:  left;
#         }    #T_b5ef3ae8_87c0_11ea_9ece_48452091a1c6row4_col1 {
#             : ;
#             text-align:  left;
#         }    #T_b5ef3ae8_87c0_11ea_9ece_48452091a1c6row4_col2 {
#             text-align:  left;
#         }    #T_b5ef3ae8_87c0_11ea_9ece_48452091a1c6row4_col3 {
#             : ;
#             text-align:  left;
#         }    #T_b5ef3ae8_87c0_11ea_9ece_48452091a1c6row4_col4 {
#             : ;
#             text-align:  left;
#         }    #T_b5ef3ae8_87c0_11ea_9ece_48452091a1c6row4_col5 {
#             : ;
#             text-align:  left;
#         }    #T_b5ef3ae8_87c0_11ea_9ece_48452091a1c6row4_col6 {
#             : ;
#             text-align:  left;
#         }    #T_b5ef3ae8_87c0_11ea_9ece_48452091a1c6row5_col0 {
#             text-align:  left;
#         }    #T_b5ef3ae8_87c0_11ea_9ece_48452091a1c6row5_col1 {
#             : ;
#             text-align:  left;
#         }    #T_b5ef3ae8_87c0_11ea_9ece_48452091a1c6row5_col2 {
#             text-align:  left;
#         }    #T_b5ef3ae8_87c0_11ea_9ece_48452091a1c6row5_col3 {
#             : ;
#             text-align:  left;
#         }    #T_b5ef3ae8_87c0_11ea_9ece_48452091a1c6row5_col4 {
#             : ;
#             text-align:  left;
#         }    #T_b5ef3ae8_87c0_11ea_9ece_48452091a1c6row5_col5 {
#             : ;
#             text-align:  left;
#         }    #T_b5ef3ae8_87c0_11ea_9ece_48452091a1c6row5_col6 {
#             : ;
#             text-align:  left;
#         }    #T_b5ef3ae8_87c0_11ea_9ece_48452091a1c6row6_col0 {
#             text-align:  left;
#         }    #T_b5ef3ae8_87c0_11ea_9ece_48452091a1c6row6_col1 {
#             : ;
#             text-align:  left;
#         }    #T_b5ef3ae8_87c0_11ea_9ece_48452091a1c6row6_col2 {
#             text-align:  left;
#         }    #T_b5ef3ae8_87c0_11ea_9ece_48452091a1c6row6_col3 {
#             : ;
#             text-align:  left;
#         }    #T_b5ef3ae8_87c0_11ea_9ece_48452091a1c6row6_col4 {
#             : ;
#             text-align:  left;
#         }    #T_b5ef3ae8_87c0_11ea_9ece_48452091a1c6row6_col5 {
#             : ;
#             text-align:  left;
#         }    #T_b5ef3ae8_87c0_11ea_9ece_48452091a1c6row6_col6 {
#             : ;
#             text-align:  left;
#         }    #T_b5ef3ae8_87c0_11ea_9ece_48452091a1c6row7_col0 {
#             text-align:  left;
#         }    #T_b5ef3ae8_87c0_11ea_9ece_48452091a1c6row7_col1 {
#             : ;
#             text-align:  left;
#         }    #T_b5ef3ae8_87c0_11ea_9ece_48452091a1c6row7_col2 {
#             text-align:  left;
#         }    #T_b5ef3ae8_87c0_11ea_9ece_48452091a1c6row7_col3 {
#             : ;
#             text-align:  left;
#         }    #T_b5ef3ae8_87c0_11ea_9ece_48452091a1c6row7_col4 {
#             : ;
#             text-align:  left;
#         }    #T_b5ef3ae8_87c0_11ea_9ece_48452091a1c6row7_col5 {
#             : ;
#             text-align:  left;
#         }    #T_b5ef3ae8_87c0_11ea_9ece_48452091a1c6row7_col6 {
#             : ;
#             text-align:  left;
#         }    #T_b5ef3ae8_87c0_11ea_9ece_48452091a1c6row8_col0 {
#             text-align:  left;
#         }    #T_b5ef3ae8_87c0_11ea_9ece_48452091a1c6row8_col1 {
#             : ;
#             text-align:  left;
#         }    #T_b5ef3ae8_87c0_11ea_9ece_48452091a1c6row8_col2 {
#             text-align:  left;
#         }    #T_b5ef3ae8_87c0_11ea_9ece_48452091a1c6row8_col3 {
#             : ;
#             text-align:  left;
#         }    #T_b5ef3ae8_87c0_11ea_9ece_48452091a1c6row8_col4 {
#             : ;
#             text-align:  left;
#         }    #T_b5ef3ae8_87c0_11ea_9ece_48452091a1c6row8_col5 {
#             : ;
#             text-align:  left;
#         }    #T_b5ef3ae8_87c0_11ea_9ece_48452091a1c6row8_col6 {
#             : ;
#             text-align:  left;
#         }    #T_b5ef3ae8_87c0_11ea_9ece_48452091a1c6row9_col0 {
#             text-align:  left;
#         }    #T_b5ef3ae8_87c0_11ea_9ece_48452091a1c6row9_col1 {
#             : ;
#             text-align:  left;
#         }    #T_b5ef3ae8_87c0_11ea_9ece_48452091a1c6row9_col2 {
#             text-align:  left;
#         }    #T_b5ef3ae8_87c0_11ea_9ece_48452091a1c6row9_col3 {
#             : ;
#             text-align:  left;
#         }    #T_b5ef3ae8_87c0_11ea_9ece_48452091a1c6row9_col4 {
#             : ;
#             text-align:  left;
#         }    #T_b5ef3ae8_87c0_11ea_9ece_48452091a1c6row9_col5 {
#             : ;
#             text-align:  left;
#         }    #T_b5ef3ae8_87c0_11ea_9ece_48452091a1c6row9_col6 {
#             : ;
#             text-align:  left;
#         }    #T_b5ef3ae8_87c0_11ea_9ece_48452091a1c6row10_col0 {
#             text-align:  left;
#         }    #T_b5ef3ae8_87c0_11ea_9ece_48452091a1c6row10_col1 {
#             : ;
#             text-align:  left;
#         }    #T_b5ef3ae8_87c0_11ea_9ece_48452091a1c6row10_col2 {
#             text-align:  left;
#         }    #T_b5ef3ae8_87c0_11

# %% [markdown]
# Creating separate Models

# %%
lr = create_model('et')
# Out:
#       Accuracy  AUC  Recall   Prec.      F1   Kappa
# 0       0.7055  0.0  0.3563  0.7044  0.6896  0.5432
# 1       0.6327  0.0  0.3496  0.6366  0.6194  0.4265
# 2       0.6569  0.0  0.4134  0.6617  0.6466  0.4692
# 3       0.6241  0.0  0.3758  0.6325  0.6097  0.4101
# 4       0.6423  0.0  0.3795  0.6500  0.6251  0.4360
# 5       0.6460  0.0  0.3907  0.6547  0.6309  0.4463
# 6       0.6131  0.0  0.3808  0.6408  0.5993  0.3868
# 7       0.6861  0.0  0.4351  0.6934  0.6753  0.5147
# 8       0.6679  0.0  0.4129  0.6610  0.6525  0.4825
# 9       0.6131  0.0  0.3240  0.6346  0.5977  0.3882
# Mean    0.6488  0.0  0.3818  0.6570  0.6346  0.4503
# SD      0.0291  0.0  0.0315  0.0233  0.0295  0.0495

# %%
xgboost = create_model('xgboost')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.8929  0.9230  0.4667  0.6364  0.5385  0.4795
# 1       0.8750  0.8708  0.4000  0.5455  0.4615  0.3927
# 2       0.8839  0.8667  0.4000  0.6000  0.4800  0.4176
# 3       0.8393  0.8460  0.2000  0.3333  0.2500  0.1663
# 4       0.9018  0.8887  0.3333  0.8333  0.4762  0.4328
# 5       0.9375  0.9711  0.7333  0.7857  0.7586  0.7228
# 6       0.8929  0.9100  0.2667  0.8000  0.4000  0.3569
# 7       0.8393  0.8835  0.3125  0.4167  0.3571  0.2674
# 8       0.8393  0.8750  0.2500  0.4000  0.3077  0.2222
# 9       0.9189  0.9667  0.5333  0.8000  0.6400  0.5964
# Mean    0.8821  0.9001  0.3896  0.6151  0.4670  0.4055
# SD      0.0326  0.0400  0.1499  0.1777  0.1447  0.1600

# %% [markdown]
# # 5. Tune Model

# %%
tuned_xgboost = tune_model('xgboost')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.9018  0.9306  0.5333  0.6667  0.5926  0.5375
# 1       0.8929  0.8653  0.6000  0.6000  0.6000  0.5381
# 2       0.8929  0.8632  0.4667  0.6364  0.5385  0.4795
# 3       0.8214  0.8199  0.4000  0.3529  0.3750  0.2713
# 4       0.9196  0.8756  0.5333  0.8000  0.6400  0.5968
# 5       0.9732  0.9814  0.8667  0.9286  0.8966  0.8812
# 6       0.9107  0.9271  0.4667  0.7778  0.5833  0.5368
# 7       0.8929  0.8874  0.5000  0.6667  0.5714  0.5116
# 8       0.8482  0.8757  0.4375  0.4667  0.4516  0.3636
# 9       0.9279  0.9715  0.5333  0.8889  0.6667  0.6291
# Mean    0.8981  0.8998  0.5338  0.6785  0.5916  0.5346
# SD      0.0395  0.0487  0.1235  0.1704  0.1307  0.1533

# %% [markdown]
# ## Ensemble Model

# %%
rf = create_model('rf')
ensembled_rf = ensemble_model(rf)
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.9018  0.9285  0.3333  0.8333  0.4762  0.4328
# 1       0.9107  0.9210  0.4667  0.7778  0.5833  0.5368
# 2       0.8750  0.8619  0.3333  0.5556  0.4167  0.3515
# 3       0.8571  0.8296  0.2000  0.4286  0.2727  0.2050
# 4       0.9107  0.8777  0.4667  0.7778  0.5833  0.5368
# 5       0.9554  0.9849  0.7333  0.9167  0.8148  0.7898
# 6       0.8839  0.9127  0.2000  0.7500  0.3158  0.2749
# 7       0.8571  0.8929  0.2500  0.5000  0.3333  0.2632
# 8       0.8661  0.8633  0.3125  0.5556  0.4000  0.3312
# 9       0.9279  0.9583  0.5333  0.8889  0.6667  0.6291
# Mean    0.8946  0.9031  0.3829  0.6984  0.4863  0.4351
# SD      0.0308  0.0450  0.1593  0.1644  0.1642  0.1761

# %% [markdown]
# ## Blend Models

# %%
#blend all models
blend_all = blend_models()

#create models for blending
xgboost = create_model('xgboost')
lightgbm = create_model('lightgbm')
et = create_model('et')

#blend trained models
blend_specific = blend_models(estimator_list = [et, lightgbm, xgboost])
# Out:
#       Accuracy  AUC  Recall   Prec.      F1   Kappa
# 0       0.8839  0.0  0.3333  0.6250  0.4348  0.3767
# 1       0.8929  0.0  0.4667  0.6364  0.5385  0.4795
# 2       0.9107  0.0  0.4000  0.8571  0.5455  0.5031
# 3       0.8393  0.0  0.2000  0.3333  0.2500  0.1663
# 4       0.9286  0.0  0.4667  1.0000  0.6364  0.6025
# 5       0.9464  0.0  0.8000  0.8000  0.8000  0.7691
# 6       0.9196  0.0  0.4667  0.8750  0.6087  0.5685
# 7       0.8929  0.0  0.5000  0.6667  0.5714  0.5116
# 8       0.8571  0.0  0.3750  0.5000  0.4286  0.3488
# 9       0.9459  0.0  0.6667  0.9091  0.7692  0.7394
# Mean    0.9017  0.0  0.4675  0.7203  0.5583  0.5065
# SD      0.0338  0.0  0.1594  0.1950  0.1547  0.1716

# %% [markdown]
# ## Stack Models

# %%
# create models for stacking
dt = create_model('dt')
rf = create_model('rf')
ada = create_model('ada')
ridge = create_model('ridge')
knn = create_model('knn')

# stack trained models
stacked_models = stack_models(estimator_list=[dt,rf,ada,ridge,knn])
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.9018  0.9450  0.4000  0.7500  0.5217  0.4726
# 1       0.8661  0.8914  0.3333  0.5000  0.4000  0.3280
# 2       0.8929  0.8777  0.4000  0.6667  0.5000  0.4442
# 3       0.8393  0.8612  0.3333  0.3846  0.3571  0.2658
# 4       0.8929  0.9038  0.3333  0.7143  0.4545  0.4037
# 5       0.9018  0.9601  0.5333  0.6667  0.5926  0.5375
# 6       0.8839  0.9189  0.2667  0.6667  0.3810  0.3297
# 7       0.8839  0.8971  0.5625  0.6000  0.5806  0.5134
# 8       0.8661  0.8984  0.3750  0.5455  0.4444  0.3713
# 9       0.9369  0.9535  0.6000  0.9000  0.7200  0.6861
# Mean    0.8866  0.9107  0.4138  0.6394  0.4952  0.4352
# SD      0.0248  0.0313  0.1068  0.1352  0.1065  0.1172

# %% [markdown]
# ## Create Stacknet

# %%
#create models for stacknet
dt = create_model('dt')
rf = create_model('rf')
ada = create_model('ada')
ridge = create_model('ridge')
knn = create_model('knn')

#create stacknet
stacknet = create_stacknet(estimator_list =[[dt,rf],[ada,ridge,knn]])
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.9018  0.9443  0.4000  0.7500  0.5217  0.4726
# 1       0.9018  0.8962  0.5333  0.6667  0.5926  0.5375
# 2       0.9107  0.8832  0.5333  0.7273  0.6154  0.5662
# 3       0.8571  0.8625  0.4667  0.4667  0.4667  0.3842
# 4       0.8929  0.9045  0.4000  0.6667  0.5000  0.4442
# 5       0.9107  0.9622  0.5333  0.7273  0.6154  0.5662
# 6       0.9107  0.9196  0.4667  0.7778  0.5833  0.5368
# 7       0.8929  0.9017  0.5625  0.6429  0.6000  0.5385
# 8       0.8929  0.9004  0.3750  0.7500  0.5000  0.4474
# 9       0.9099  0.9507  0.6000  0.6923  0.6429  0.5916
# Mean    0.8981  0.9125  0.4871  0.6867  0.5638  0.5085
# SD      0.0155  0.0299  0.0731  0.0841  0.0578  0.0638

# %% [markdown]
# ## ROC Curve Plot

# %%
rf = create_model('et')
plot_model(estimator = rf, plot = 'auc')

# %%
interpret_model(rf)
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: (Type Error): This function only supports tree based models for binary classification.

# %% [markdown]
# ## Evaluating a model

# %%
#create a model
rf = create_model('rf')
#evaluate a model
evaluate_model(rf)
# Out:
#                                                                             Parameters
# estimator__bootstrap                                                              True
# estimator__ccp_alpha                                                                 0
# estimator__class_weight                                                           None
# estimator__criterion                                                              gini
# estimator__max_depth                                                              None
# estimator__max_features                                                           auto
# estimator__max_leaf_nodes                                                         None
# estimator__max_samples                                                            None
# estimator__min_impurity_decrease                                                     0
# estimator__min_impurity_split                                                     None
# estimator__min_samples_leaf                                                          1
# estimator__min_samples_split                                                         2
# estimator__min_weight_fraction_leaf                                                  0
# estimator__n_estimators                                                             10
# estimator__n_jobs                                                                 None
# estimator__oob_score                                                             False
# estimator__random_state                                                            123
# estimator__verbose                                                                   0
# estimator__warm_start                                                            False
# estimator                            RandomForestClassifier(bootstrap=True, ccp_alp...
# n_jobs                                                                            None

# %% [markdown]
# ## Interpreting a Model

# %%
xgboost = create_model('xgboost')
interpret_model(xgboost)
# Out:
#       Accuracy  AUC  Recall   Prec.      F1   Kappa
# 0       0.6436  0.0  0.3026  0.6596  0.6201  0.4371
# 1       0.5818  0.0  0.2707  0.5781  0.5584  0.3360
# 2       0.5803  0.0  0.5077  0.5970  0.5620  0.3354
# 3       0.6204  0.0  0.3693  0.6483  0.6031  0.4003
# 4       0.5657  0.0  0.3009  0.5609  0.5354  0.3011
# 5       0.5584  0.0  0.3098  0.5876  0.5391  0.3014
# 6       0.5730  0.0  0.3037  0.5715  0.5440  0.3146
# 7       0.5584  0.0  0.2924  0.5269  0.5331  0.3052
# 8       0.6168  0.0  0.3726  0.6224  0.5957  0.3905
# 9       0.5401  0.0  0.2685  0.5330  0.5192  0.2653
# Mean    0.5839  0.0  0.3298  0.5885  0.5610  0.3387
# SD      0.0311  0.0  0.0681  0.0423  0.0323  0.0511
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: (Type Error): This function only supports tree based models for binary classification.

# %% [markdown]
# # 6. Save Model

# %%
#save trained model
save_model(xgboost, 'xgboost_model_04242020')
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
# Transformation Pipeline and Model Succesfully Saved

# %% [markdown]
# # 7. Save Experiment

# %%
save_experiment('experiment_04242020')
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
# Experiment Succesfully Saved

# %% [markdown]
# ## End of Notebook
